# %% [markdown]
# Created by: Michał Pilichowski (pjatk student number s22215)

# %% [markdown]
# Install project repo.

# %%
# !pip install --upgrade git+git://github.com/pilichm/ZUMNLP_PROJ2.git

# %%
# !python -m spacy download pl_core_news_sm

# %% [markdown]
# Import required libraries.

# %%
import pandas as pd

from pilichm.main.ClassicML import run_classical_model
from pilichm.main.NeuralNetworkModel import run_neural_network_model
from pilichm.main import Utils
from pilichm.main.Utils import display_sentiment_distribution

# %% [markdown]
# Download project repo.

# %%
# !git clone https://github.com/pilichm/ZUMNLP_PROJ2.git

# %% [markdown]
# Set path to dataset. Leave default value to use data from project repo.

# %%
PATH_TO_DATA = '/content/ZUMNLP_PROJ2/data/twitter.csv'

# %% [markdown]
# Clean tweet data.

# %%
Utils.clean_data(path_to_csv=PATH_TO_DATA)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2828: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):

# %% [markdown]
# Add sentiment to data.

# %%
Utils.create_labels(path_to_csv=PATH_TO_DATA)
# Out:
# <class 'str'>
# boję wirusa hshshshsh coronaviru
# <class 'list'>
# ['boję', 'wirusa', 'hshshshsh', 'coronaviru']
# -1    69016
#  0     1837
#  1      813
# Name: sentiment, dtype: int64

# %% [markdown]
# Display sentiment distribution.

# %%
display_sentiment_distribution(path_to_csv=PATH_TO_DATA)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2828: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):

# %% [markdown]
# Run GaussianNB.

# %%
run_classical_model(path_to_csv='/content/ZUMNLP_PROJ2/data/twitter.csv', model_name='GaussianNB', display_diagrams=True)
# Out:
# Label neg distribution:
# Actual: Counter({1.0: 19232, 0.0: 2268})
# ...

# %% [markdown]
# Run SVC with linear kernel.

# %%
run_classical_model(path_to_csv='/content/ZUMNLP_PROJ2/data/twitter.csv', model_name='SVC', display_diagrams=True)
# Out:
# Label neg distribution:
# Actual: Counter({1.0: 19232, 0.0: 2268})
# ...

# %% [markdown]
# Run LogisticRegression.

# %%
run_classical_model(path_to_csv='/content/ZUMNLP_PROJ2/data/twitter.csv', model_name='LogisticRegression', display_diagrams=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# Label neg distribution:
# Actual: Counter({1.0: 19232, 0.0: 2268})
# ...

# %% [markdown]
# Run neural network model.

# %%
run_neural_network_model(path_to_csv='/content/ZUMNLP_PROJ2/data/twitter.csv', display_diagrams=True, read_model=False, save_model=True)
# Out:
# 0    1    2
# 0.0  1.0  0.0    19195
# 1.0  0.0  0.0     1175
# 0.0  0.0  1.0     1130
# dtype: int64
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  embedding (Embedding)       (None, 200, 40)           200000
#
#  conv1d (Conv1D)             (None, 195, 20)           4820
#
#  max_pooling1d (MaxPooling1D  (None, 39, 20)           0
#  )
#
#  bidirectional (Bidirectiona  (None, 40)               6560
#  l)
#
#  dense (Dense)               (None, 3)                 123
#
# ...
# Total params: 211,503
# Trainable params: 211,503
# Non-trainable params: 0
# _________________________________________________________________
# None
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/25
# 1568/1568 [==============================] - ETA: 0s - loss: 0.4369 - accuracy: 0.8948
# ...
